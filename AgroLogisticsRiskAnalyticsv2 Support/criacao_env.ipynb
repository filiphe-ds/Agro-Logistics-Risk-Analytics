# %%
env_content = """
GEMINI_API_KEY=AIzaSyCSZM2XCSRkGKyiYfI4Z6Q0UZTj5bqSVJs
VC_API_KEY=R47M33P2WMALNZV77NGZSDP6N
PROJECT_ID=agrologisticsdata
"""

with open(".env", "w") as f:
    f.write(env_content.strip())

print("✅ Arquivo .env criado com sucesso!")
# Out:
# ✅ Arquivo .env criado com sucesso!
